# %% [markdown]
# ### 1. Import

# %%
cd c:\Users\nlinl\Desktop\Important\EECS6892\project\soccer_twos
# Out:
# c:\Users\nlinl\Desktop\Important\EECS6892\project\soccer_twos
# c:\Users\nlinl\anaconda3\envs\rl\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# import packages
import time
import os
import torch
from torch import nn
from collections import deque
import numpy as np
import matplotlib.pyplot as plt
from mlagents_envs.environment import UnityEnvironment as UE

# %%
# import modules
from environment import SoccerTwosEnvWrapper
from agents.dqn import DeepQN
from models.models import *

# %%
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ### 2. Initialization

# %%
# in case set up fails
try:
    ue.close()
except:
    pass

# %%
# start up environment
root = r'C:/Users/nlinl/Desktop/Important/EECS6892/project/ml-agents/training-envs-executables'
ue = UE(file_name = root + '/' +'SoccerTwos.exe')
env = SoccerTwosEnvWrapper(ue)

# %% [markdown]
# ### 3. Deep Q-Learning

# %% [markdown]
# #### Training

# %%
"""
training DQN models
"""
#TODO: CHANGE ACTION TO JUST BE DECISION VALUES FOR THE 3 DIRECTIONS (this way it makes it easier to compute q values)
# IDEA: output a (9,) tensor -> reshape to (3,3) -> choose actions by taking argmax of dim = 0 ->  
# OR: figure out how to work out a way to match the q values from the target to the q values for the model
# init training parameters
gamma = 0.99 # discount factor
update_after_actions = 256 # number of actions per model update
target_update_after_actions = 1000 # number of actions per target model update
update_generation_after_episodes = 100
MAX_EPISODES = 50000 # number of episodes
MAX_STEPS_PER_EPISODE = 1000 # number of steps per episode
target_reward = 0.8 # desired reward for model
epsilon = np.linspace(1, 0.001, MAX_EPISODES) # TODO: modify this to another epsilon scheme?
learning_rate = 0.0005 # model learning rate
batch_size = 128 # training batch size
gamma = 0.99 # rewards discount factor
penalty = 0.0 # episode done penalty
max_memory = 10000 # maximum experience replay memory
last_n_reward = 100 # last n rewards considered for running rewards 

# init agents
num_agents = env.num_agents
agents = [DeepQN(
    model = LinearModel,
    in_size = env.obssize,
    out_size = env.actsize,
    learning_rate = learning_rate,
    batch_size = batch_size,
    gamma = gamma,
    penalty = penalty,
    max_memory = max_memory,
    last_n_reward = last_n_reward
) for _ in range(num_agents)]

# training loop
action_count = 0 # track number of steps passed during training
start_time = time.time()
target_met = False
generation_count = 0

try:

    for episode in range(MAX_EPISODES):

        states = np.array(env.reset())
        episode_start = time.time()

        for timestep in range(1, MAX_STEPS_PER_EPISODE):

            action_count += 1

            actions = [None] * num_agents
            
            # choosing action
            for a in range(num_agents):

                # get agent
                agent = agents[a]

                # epsilon-exploration
                if np.random.rand() < epsilon[episode]:
                    action = env.get_random_action(a)
                else:
                    state_t = torch.tensor(states[a])
                    state_t = torch.unsqueeze(state_t, 0)
                    action = agent.sample_action_from_policy(state_t)

                actions[a] = action

            # set action in environment
            for a, action in enumerate(actions):
                
                env.set_action(a, action)
            
            # take step in environment
            next_states, rewards, dones = env.step()

            # update replay history buffers
            for a in range(num_agents):
                
                # get agent
                agent = agents[a]
                
                # get transition
                state = states[a]
                action = actions[a] 
                next_state = np.array(next_states[a])
                reward = rewards[a]
                done = dones[a]
                
                # update agent replay buffer
                agent.update_replay_history(state, action, next_state, reward, done)

            states = next_states

            # updating models of each agent
            if action_count % update_after_actions == 0:

                for agent in agents:

                    # update model
                    agent.update()

            # updating target models
            if action_count % target_update_after_actions == 0:

                for a in range(num_agents):

                    # get agent
                    agent = agents[a]

                    # update target models
                    agent.update_target()

                    # print progress
                    episode_end = time.time()
                    agent.print_training_progress(a, action_count, generation_count, episode_end - episode_start, episode_end - start_time)

                    # update running rewards
                    agent.update_running_rewards()
                
                print( '#'*150)
            
            # trim replay buffer
            for agent in agents:
                agent.trim_reward_history()
            
            # end episode
            if done:
                break

        # save episode rewards
        for agent in agents:

            agent.update_episode_reward()


        # get best performing agent of current episode
        best_running_reward = -float('inf')
        best_agent = None
        for agent in agents:
            
            rr = agent.get_running_reward()
            if rr > best_running_reward:
                best_running_reward = rr
                best_agent = agent

        # check if target reward has been met by any agent
        if episode > 100 and best_running_reward > target_reward:
            print('target reward met')
            break

        # update models to the current best performing instance
        if episode > 0 and episode % update_generation_after_episodes == 0:            
            # set agent's base and target models to the best model
            for agent in agents:

                if agent == best_agent: continue

                agent.update_generation(best_agent)

            generation_count += 1

        # save best model weights
        log_episode = int(np.log10(episode)) if episode > 0 else 0
        # determine the increment of episodes bw each save
        save_increment = 10**log_episode
        if save_increment > 1 and episode % save_increment == 0:                
            best_agent.save_model(f'best_{episode}')

except KeyboardInterrupt:
    
    pass

# close environment
env.close()


# get best agent
if not target_met:

    best_rr = -float('inf')
    best_agent = None

    for agent in agents:

        rr = agent.get_running_reward()
        if rr > best_rr:
            best_rr = rr
            best_agent = agent

# save best agent's weights
print(f"saving best agent: running reward = {best_rr}")
best_agent.save_model('last')

# plot training results of bet agent
best_agent.plot_running_rewards(target_update_after_actions)
# Out:
# AGENT 0, EPISODE 1, FRAME 1000, GENERATION 0: last reward = 0.09, running reward =  0.09, episode time = 0.06, total time = 99.71
# AGENT 1, EPISODE 1, FRAME 1000, GENERATION 0: last reward = 0.09, running reward =  0.09, episode time = 0.06, total time = 99.71
# AGENT 2, EPISODE 1, FRAME 1000, GENERATION 0: last reward = -1.00, running reward =  -1.00, episode time = 0.06, total time = 99.71
# AGENT 3, EPISODE 1, FRAME 1000, GENERATION 0: last reward = -1.00, running reward =  -1.00, episode time = 0.07, total time = 99.71
# ########################################
# AGENT 0, EPISODE 7, FRAME 2000, GENERATION 0: last reward = 0.00, running reward =  -0.05, episode time = 8.69, total time = 199.54
# AGENT 1, EPISODE 7, FRAME 2000, GENERATION 0: last reward = 0.00, running reward =  -0.05, episode time = 8.69, total time = 199.55
# AGENT 2, EPISODE 7, FRAME 2000, GENERATION 0: last reward = 0.00, running reward =  -0.43, episode time = 8.69, total time = 199.55
# AGENT 3, EPISODE 7, FRAME 2000, GENERATION 0: last reward = 0.00, running reward =  -0.43, episode time = 8.69, total time = 199.55
# ########################################
# weights saved at /weights/dqn_best_10.pt
# AGENT 0, EPISODE 15, FRAME 3000, GENERATION 0: last reward = 0.00, running reward =  0.05, episode time = 8.50, total time = 299.35
# AGENT 2, EPISODE 4366, FRAME 562000, GENERATION 43: last reward = 0.00, running reward =  -0.13, episode time = 8.40, total time = 96644.76
# AGENT 3, EPISODE 4366, FRAME 562000, GENERATION 43: last reward = 0.00, running reward =  -0.13, episode time = 8.40, total time = 96644.76
# ########################################
# AGENT 0, EPISODE 4375, FRAME 563000, GENERATION 43: last reward = 0.38, running reward =  -0.14, episode time = 3.00, total time = 96744.52
# AGENT 1, EPISODE 4375, FRAME 563000, GENERATION 43: last reward = 0.38, running reward =  -0.15, episode time = 3.00, total time = 96744.52
# AGENT 2, EPISODE 4375, FRAME 563000, GENERATION 43: last reward = 0.38, running reward =  -0.14, episode time = 3.00, total time = 96744.53
# AGENT 3, EPISODE 4375, FRAME 563000, GENERATION 43: last reward = 0.38, running reward =  -0.14, episode time = 3.00, total time = 96744.53
# ########################################
# AGENT 0, EPISODE 4384, FRAME 564000, GENERATION 43: last reward = 0.56, running reward =  -0.14, episode time = 28.90, total time = 96844.24
# AGENT 1, EPISODE 4384, FRAME 564000, GENERATION 43: last reward = 0.56, running reward =  -0.15, episode time = 28.90, total time = 96844.25
# AGENT 2, EPISODE 4384, FRAME 564000, GENERATION 43: last reward = 0.56, running reward =  -0.15, episode time = 28.91, total time = 96844.25
# AGENT 3, EPISODE 4384, FRAME 564000, GENERATION 43: last reward = 0.56, running reward =  -0.14, episode time = 28.91, total time = 96844.25
# ########################################
# AGENT 0, EPISODE 4390, FRAME 565000, GENERATION 43: last reward = 0.00, running reward =  -0.12, episode time = 28.80, total time = 96944.14
# AGENT 1, EPISODE 4390, FRAME 565000, GENERATION 43: last reward = 0.00, running reward =  -0.11, episode time = 28.81, total time = 96944.16
# AGENT 2, EPISODE 4390, FRAME 565000, GENERATION 43: last reward = 0.00, running reward =  -0.11, episode time = 28.82, total time = 96944.16
# AGENT 3, EPISODE 4390, FRAME 565000, GENERATION 43: last reward = 0.00, running reward =  -0.11, episode time = 28.82, total time = 96944.16
# ########################################
# AGENT 0, EPISODE 4396, FRAME 566000, GENERATION 43: last reward = 0.00, running reward =  -0.08, episode time = 28.60, total time = 97043.94
# AGENT 1, EPISODE 4396, FRAME 566000, GENERATION 43: last reward = 0.00, running reward =  -0.07, episode time = 28.60, total time = 97043.94
# AGENT 2, EPISODE 4396, FRAME 566000, GENERATION 43: last reward = 0.00, running reward =  -0.08, episode time = 28.60, total time = 97043.94
# AGENT 3, EPISODE 4396, FRAME 566000, GENERATION 43: last reward = 0.00, running reward =  -0.09, episode time = 28.60, total time = 97043.94
# ########################################
# AGENT 0, EPISODE 4405, FRAME 567000, GENERATION 44: last reward = -1.00, running reward =  -0.11, episode time = 12.50, total time = 97143.66
# AGENT 1, EPISODE 4405, FRAME 567000, GENERATION 44: last reward = -1.00, running reward =  -0.11, episode time = 12.50, total time = 97143.66
# AGENT 2, EPISODE 4405, FRAME 567000, GENERATION 44: last reward = -1.00, running reward =  -0.11, episode time = 12.50, total time = 97143.66
# AGENT 3, EPISODE 4405, FRAME 567000, GENERATION 44: last reward = -1.00, running reward =  -0.11, episode time = 12.51, total time = 97143.67
# ########################################
# AGENT 0, EPISODE 4417, FRAME 568000, GENERATION 44: last reward = 0.19, running reward =  -0.13, episode time = 10.60, total time = 97243.22
# AGENT 1, EPISODE 4417, FRAME 568000, GENERATION 44: last reward = 0.19, running reward =  -0.14, episode time = 10.60, total time = 97243.22
# AGENT 2, EPISODE 4417, FRAME 568000, GENERATION 44: last reward = 0.19, running reward =  -0.14, episode time = 10.60, total time = 97243.22
# AGENT 3, EPISODE 4417, FRAME 568000, GENERATION 44: last reward = 0.19, running reward =  -0.14, episode time = 10.60, total time = 97243.22
# ########################################
# AGENT 0, EPISODE 4424, FRAME 569000, GENERATION 44: last reward = 0.00, running reward =  -0.15, episode time = 10.46, total time = 97343.12
# AGENT 1, EPISODE 4424, FRAME 569000, GENERATION 44: last reward = 0.00, running reward =  -0.14, episode time = 10.47, total time = 97343.12
# AGENT 2, EPISODE 4424, FRAME 569000, GENERATION 44: last reward = 0.00, running reward =  -0.15, episode time = 10.47, total time = 97343.12
# AGENT 3, EPISODE 4424, FRAME 569000, GENERATION 44: last reward = 0.00, running reward =  -0.16, episode time = 10.47, total time = 97343.12
# ########################################
# AGENT 0, EPISODE 4429, FRAME 570000, GENERATION 44: last reward = -1.00, running reward =  -0.14, episode time = 10.41, total time = 97443.03
# AGENT 1, EPISODE 4429, FRAME 570000, GENERATION 44: last reward = -1.00, running reward =  -0.13, episode time = 10.41, total time = 97443.03
# AGENT 2, EPISODE 4429, FRAME 570000, GENERATION 44: last reward = -1.00, running reward =  -0.14, episode time = 10.41, total time = 97443.03
# AGENT 3, EPISODE 4429, FRAME 570000, GENERATION 44: last reward = -1.00, running reward =  -0.15, episode time = 10.41, total time = 97443.03
# ########################################
# AGENT 0, EPISODE 4435, FRAME 571000, GENERATION 44: last reward = 0.22, running reward =  -0.18, episode time = 25.39, total time = 97542.80
# AGENT 1, EPISODE 4435, FRAME 571000, GENERATION 44: last reward = 0.22, running reward =  -0.18, episode time = 25.40, total time = 97542.80
# AGENT 2, EPISODE 4435, FRAME 571000, GENERATION 44: last reward = 0.22, running reward =  -0.18, episode time = 25.40, total time = 97542.80
# AGENT 3, EPISODE 4435, FRAME 571000, GENERATION 44: last reward = 0.22, running reward =  -0.18, episode time = 25.40, total time = 97542.80
# ########################################
# AGENT 0, EPISODE 4441, FRAME 572000, GENERATION 44: last reward = 0.00, running reward =  -0.17, episode time = 25.20, total time = 97642.59
# AGENT 1, EPISODE 4441, FRAME 572000, GENERATION 44: last reward = 0.00, running reward =  -0.17, episode time = 25.20, total time = 97642.60
# AGENT 2, EPISODE 4441, FRAME 572000, GENERATION 44: last reward = 0.00, running reward =  -0.17, episode time = 25.20, total time = 97642.60
# AGENT 3, EPISODE 4441, FRAME 572000, GENERATION 44: last reward = 0.00, running reward =  -0.17, episode time = 25.20, total time = 97642.60
# ########################################
# AGENT 0, EPISODE 4450, FRAME 573000, GENERATION 44: last reward = 0.00, running reward =  -0.15, episode time = 24.91, total time = 97742.31
# AGENT 2, EPISODE 4488, FRAME 578000, GENERATION 44: last reward = 0.00, running reward =  -0.09, episode time = 16.15, total time = 98243.76
# AGENT 3, EPISODE 4488, FRAME 578000, GENERATION 44: last reward = 0.00, running reward =  -0.09, episode time = 16.15, total time = 98243.77
# ########################################
# AGENT 0, EPISODE 4494, FRAME 579000, GENERATION 44: last reward = 0.00, running reward =  -0.07, episode time = 13.30, total time = 98360.81
# AGENT 1, EPISODE 4494, FRAME 579000, GENERATION 44: last reward = 0.00, running reward =  -0.07, episode time = 13.30, total time = 98360.81
# AGENT 2, EPISODE 4494, FRAME 579000, GENERATION 44: last reward = 0.00, running reward =  -0.07, episode time = 13.30, total time = 98360.81
# AGENT 3, EPISODE 4494, FRAME 579000, GENERATION 44: last reward = 0.00, running reward =  -0.07, episode time = 13.30, total time = 98360.81
# ########################################
# AGENT 0, EPISODE 4502, FRAME 580000, GENERATION 45: last reward = 0.00, running reward =  -0.08, episode time = 13.11, total time = 98460.61
# AGENT 1, EPISODE 4502, FRAME 580000, GENERATION 45: last reward = 0.00, running reward =  -0.08, episode time = 13.11, total time = 98460.61
# AGENT 2, EPISODE 4502, FRAME 580000, GENERATION 45: last reward = 0.00, running reward =  -0.08, episode time = 13.11, total time = 98460.62
# AGENT 3, EPISODE 4502, FRAME 580000, GENERATION 45: last reward = 0.00, running reward =  -0.08, episode time = 13.11, total time = 98460.62
# ########################################
# saving best agent: running reward = -0.08676799975335597
# weights saved at /weights/dqn_last.pt
# saved running rewards at /plots/dqn_running_rewards.csv
# plot saved at /plots/dqn_training_plot.png

# %% [markdown]
# #### Testing
# (Run initialization again)

# %%
TEST_EPISODES = 100
episode_rewards = []
num_agents = env.num_agents
path_to_weights = './weights/dqn_best_3000.pt'
 
num_agents = env.num_agents
agents = [DeepQN(
    model = LinearModel,
    in_size = env.obssize,
    out_size = env.actsize,
) for _ in range(num_agents)]

# load model
for agent in agents:
    agent.model.load_state_dict(torch.load(path_to_weights))

for episode in range(TEST_EPISODES):

    states = np.array(env.reset())
    done = False
    episode_reward = [0]*num_agents

    while not done:
    
        # choosing action
        actions = [None] * num_agents

        for a in range(num_agents):

            # get agent
            agent = agents[a]
            
            state_t = torch.tensor(states[a])
            state_t = torch.unsqueeze(state_t, 0)
            action = agent.sample_action_from_policy(state_t)

            actions[a] = action

        # set action in environment
        for a, action in enumerate(actions):
            
            env.set_action(a, action)

        # take step in environment
        next_states, rewards, dones = env.step()
        
        # update rewards
        for a in range(num_agents):
            episode_reward[a] += rewards[a]

        # state transition 
        states = next_states
        done = np.all(dones)

    episode_rewards.append(episode_reward)
    
    # print progress
    for a, agent in enumerate(agents):
        agent.print_testing_progrees(a, episode, episode_reward[a])
    print( '#'*40)


# plot test rewards
plt.plot(np.arange(1, TEST_EPISODES+1, 1), episode_rewards)
plt.title('episode rewards against episode count')
plt.xlabel('episode')
plt.ylabel('reward')
plt.legend()
plt.show()
plt.savefig('./plots/dqn_testing_plot.png')
print('plot saved at /plots/dqn_testing_plot.png')
# Out:
# AGENT 0, EPISODE 0: reward -1.00
# AGENT 1, EPISODE 0: reward -1.00
# AGENT 2, EPISODE 0: reward 0.58
# AGENT 3, EPISODE 0: reward 0.58
# ########################################
# AGENT 0, EPISODE 1: reward -1.00
# AGENT 1, EPISODE 1: reward -1.00
# AGENT 2, EPISODE 1: reward 0.56
# AGENT 3, EPISODE 1: reward 0.56
# ########################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 45
#      42     env.set_action(a, action)
#      44 # take step in environment
# ---> 45 next_states, rewards, dones = env.step()
#      47 # update rewards
#      48 for a in range(num_agents):
#
# File c:\Users\nlinl\Desktop\Important\EECS6892\project\soccer_twos\environment.py:79, in SoccerTwosEnvWrapper.step(self)
#      76     raise Exception('Train Error: Not all actions are set for every agent')
#      78 # take step
# ---> 79 self.env.step()
#      81 # update environment variables
#      82 self.update_steps()
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\site-packages\mlagents_envs\timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\site-packages\mlagents_envs\environment.py:348, in UnityEnvironment.step(self)
#     346 step_input = self._generate_step_input(self._env_actions)
#     347 with hierarchical_timer("communicator.exchange"):
# --> 348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
#     350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\site-packages\mlagents_envs\rpc_communicator.py:142, in RpcCommunicator.exchange(self, inputs, poll_callback)
#     140 message.unity_input.CopyFrom(inputs)
#     141 self.unity_to_external.parent_conn.send(message)
# --> 142 self.poll_for_timeout(poll_callback)
#     143 output = self.unity_to_external.parent_conn.recv()
#     144 if output.header.status != 200:
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\site-packages\mlagents_envs\rpc_communicator.py:106, in RpcCommunicator.poll_for_timeout(self, poll_callback)
#     104 callback_timeout_wait = self.timeout_wait // 10
#     105 while time.monotonic() < deadline:
# --> 106     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#     107         # Got an acknowledgment from the connection
#     108         return
#     109     if poll_callback:
#     110         # Fire the callback - if it detects something wrong, it should raise an exception.
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\multiprocessing\connection.py:330, in PipeConnection._poll(self, timeout)
#     327 if (self._got_empty_message or
#     328             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329     return True
# --> 330 return bool(wait([self], timeout))
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\multiprocessing\connection.py:879, in wait(object_list, timeout)
#     876                 ready_objects.add(o)
#     877                 timeout = 0
# --> 879     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     880 finally:
#     881     # request that overlapped reads stop
#     882     for ov in ov_list:
#
# File c:\Users\nlinl\anaconda3\envs\rl\lib\multiprocessing\connection.py:811, in _exhaustive_wait(handles, timeout)
#     809 ready = []
#     810 while L:
# --> 811     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     812     if res == WAIT_TIMEOUT:
#     813         break
#
# KeyboardInterrupt:
